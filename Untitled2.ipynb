# %% [markdown]
# <a href="https://colab.research.google.com/github/andrey0000981/labpython/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import CoolProp.CoolProp as ct 
T = 273.15
P = 101300
R = 8
V = 64
M = 0.016
T = np.linspace(100,150,1000)
Fluid_name = 'CH4'
# reshenie 1
m1 = (P*M*V)/(R*T) 




# reshenie 2


D = ct.PropsSI('D','T',T,'P',P,'CH4')
m2 = D * V


# graphika

plt.plot(T,m1,'b')
plt.plot(T,m2,'r')
plt.xlabel('T')
plt.ylabel('m')
plt.title('Зависимость m от T при постоянном давлении')
plt.legend(['m школьная','m coolprop'])
plt.scatter(112.14,ct.PropsSI('D','T',373,'P',P,'CH4'),color = 'black')
